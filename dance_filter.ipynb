# %%
import pandas as pd 
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('cleaned_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0            track_name        artist  duration_min  release_year  \
# 0         733  He Wasn't Man Enough  Toni Braxton           4.4          2000
# 1         734  He Wasn't Man Enough  Toni Braxton           4.4          2000
# 2         735  He Wasn't Man Enough  Toni Braxton           4.4          2000
# 3         736  He Wasn't Man Enough  Toni Braxton           4.4          2000
# 4         737  He Wasn't Man Enough  Toni Braxton           4.4          2000
#
#    popularity  followers  chart_week  list_position                track_id  \
# 0          65    4234164  2000-05-06              2  7f1Dmr246cJ9uQYdbplTbh
# 1          65    4234164  2000-05-13              2  7f1Dmr246cJ9uQYdbplTbh
# 2          65    4234164  2000-04-29              3  7f1Dmr246cJ9uQYdbplTbh
# 3          65    4234164  2000-05-20              4  7f1Dmr246cJ9uQYdbplTbh
# 4          65    4234164  2000-05-27              4  7f1Dmr246cJ9uQYdbplTbh
#
#                 artist_id  danceability  energy   key  loudness  mode  \
# 0  3X458ddYA2YcVWuVIGGOYe         0.739   0.947  11.0    -1.916   0.0
# 1  3X458ddYA2YcVWuVIGGOYe         0.739   0.947  11.0    -1.916   0.0
# 2  3X458ddYA2YcVWuVIGGOYe         0.739   0.947  11.0    -1.916   0.0
# 3  3X458ddYA2YcVWuVIGGOYe         0.739   0.947  11.0    -1.916   0.0
# 4  3X458ddYA2YcVWuVIGGOYe         0.739   0.947  11.0    -1.916   0.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence  tempo
# 0       0.0411       0.00916          0.000031     0.326    0.766     88
# 1       0.0411       0.00916          0.000031     0.326    0.766     88
# 2       0.0411       0.00916          0.000031     0.326    0.766     88
# 3       0.0411       0.00916          0.000031     0.326    0.766     88
# 4       0.0411       0.00916          0.000031     0.326    0.766     88

# %%
data["dancing_music"] = (
    (data["danceability"].between(0.7, 1)) &
    (data["tempo"].between(85, 140)) &
    (data["energy"].between(0.7, 1)) &
    (data["valence"].between(0.6, 1)) &
    (data["loudness"].between(-6, 0)) &
    (data["acousticness"].between(0.0, 0.3)) &
    (data["instrumentalness"].between(0.0, 0.5))
).astype(int)
dancing_music = data[data["dancing_music"] == 1]
dancing_music_unique = dancing_music .drop_duplicates(subset="track_name", keep='first')

# %%
dancing_music_unique
# Out:
#        Unnamed: 0                                         track_name  \
# 0             733                               He Wasn't Man Enough
# 46            779                              Shackles (Praise You)
# 152           885                               Who Let The Dogs Out
# 221           954                                     Gotta Tell You
# 388          1121              Baby Come On Over (This Is Our Night)
# ...           ...                                                ...
# 57242      125937  Lolli Lolli (Pop That Body) (feat. Project Pat...
# 57621      126316                                           Funhouse
# 57837      126532                                     I Love College
# 58555      127250                                             Insane
# 59190      127885                            Spotlight (feat. Usher)
#
#                artist  duration_min  release_year  popularity  followers  \
# 0        Toni Braxton           4.4          2000          65    4234164
# 46          Mary Mary           3.3          2000          54     652139
# 152          Baha Men           3.3          2000          51      56279
# 221    Samantha Mumba           3.3          2000          46     184635
# 388    Samantha Mumba           3.5          2000          46     184635
# ...               ...           ...           ...         ...        ...
# 57242     Project Pat           4.2          2008          68     872228
# 57621            P!nk           3.4          2008          82   17190703
# 57837      Asher Roth           4.0          2009          45     243791
# 58555          Eminem           3.0          2009          93   91487128
# 59190      Gucci Mane           3.9          2009          77    5661054
#
#        chart_week  list_position                track_id  \
# 0      2000-05-06              2  7f1Dmr246cJ9uQYdbplTbh
# 46     2000-05-13             28  7JKEA8xYDoFp4q0QBW2PGg
# 152    2000-10-21             40  1H5tvpoApNDxvxDexoaAUo
# 221    2000-12-09              4  1rj0XawWJNisX7SGYexowJ
# 388    2001-06-09             49  514AneEN1C63hmnVNC4dLJ
# ...           ...            ...                     ...
# 57242  2008-08-16             18  4xWMTkwknjh8FzxNrkwLl6
# 57621  2009-11-14             44  1uexV2mYuZmLhVz4G5LUZv
# 57837  2009-04-11             12  1akgiRM3mN2nxu2AX6ACCW
# 58555  2009-06-06             85  6x1stxDsnh4ZlEft29uhlR
# 59190  2009-12-26             42  4LvH604nVCMVGlNbjx3Gnk
#
#                     artist_id  danceability  energy   key  loudness  mode  \
# 0      3X458ddYA2YcVWuVIGGOYe         0.739   0.947  11.0    -1.916   0.0
# 46     12Kgt2eahvxNWhD5PnSUde         0.779   0.834   7.0    -2.773   1.0
# 152    67FFKYikvTlvsPNk4NPOYJ         0.869   0.887   0.0    -4.505   1.0
# 221    7L12TqJ0fbwtFljTbwfwRI         0.739   0.750   0.0    -4.513   0.0
# 388    7L12TqJ0fbwtFljTbwfwRI         0.758   0.820   2.0    -4.420   0.0
# ...                       ...           ...     ...   ...       ...   ...
# 57242  08Ld63UgKrJ0nZnCkzHtzc         0.890   0.946   2.0    -5.673   1.0
# 57621  1KCSPY1glIKqW2TotWuXOR         0.792   0.864  11.0    -3.040   0.0
# 57837  1wgY8huggK60P5nvYrwcYT         0.713   0.826   8.0    -4.075   1.0
# 58555  7dGJo4pcD2V6oG8kP0tJRR         0.876   0.878   9.0    -0.929   0.0
# 59190  13y7CgLHjMVRMDqxdx0Xdo         0.781   0.784  10.0    -5.047   0.0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  tempo  \
# 0           0.0411       0.00916          0.000031    0.3260    0.766     88
# 46          0.1620       0.03430          0.000000    0.0886    0.800    100
# 152         0.0992       0.06050          0.000000    0.1480    0.784    129
# 221         0.0278       0.20500          0.000000    0.1570    0.758    110
# 388         0.0755       0.02530          0.001050    0.0697    0.801     95
# ...            ...           ...               ...       ...      ...    ...
# 57242       0.0489       0.01880          0.000128    0.1100    0.872    120
# 57621       0.0338       0.00503          0.000002    0.0375    0.832    104
# 57837       0.2430       0.08970          0.000000    0.4210    0.664     86
# 58555       0.1680       0.25100          0.000000    0.3210    0.677     98
# 59190       0.1300       0.07740          0.000000    0.3650    0.738    125
#
#        dancing_music
# 0                  1
# 46                 1
# 152                1
# 221                1
# 388                1
# ...              ...
# 57242              1
# 57621              1
# 57837              1
# 58555              1
# 59190              1
#
# [225 rows x 23 columns]

# %%
dancing_music_unique['duration_min'].sum()/60
# Out:
# np.float64(14.203333333333331)
