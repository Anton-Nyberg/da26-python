# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # ELC

# %% [markdown]
# ## Loading data

# %%
from google.auth import load_credentials_from_file
from google.cloud.bigquery import Client

# %%
credentials, project_id = load_credentials_from_file('service_account.json')

# %%
# Load data from BigQuery
client = Client(
    project = project_id,
    credentials=credentials
)

# %%
query = "SELECT * FROM `da26-python.music_data.tracks`"

# %%
load_job = client.query(query)

# %%
data = load_job.to_dataframe()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
def load_data(table):
    query = f"SELECT * FROM `da26-python.music_data.{table}`"
    load_job = client.query(query)
    data = load_job.to_dataframe()
    return data

# %%
artists = load_data('artists')

# %%
audio_features = load_data('audio_features')

# %%
chart_positions = load_data('chart_positions')

# %%
mapping = load_data('tracks_artists_mapping')

# %%
tracks = load_data('tracks')

# %% [markdown]
# ## Joining data
#
# Joining "tracks", "artists"

# %%
data = tracks.merge(mapping, on = 'track_id' )

# %%
data = data.merge(artists, on = 'artist_id')

# %%
data.rename(columns = {'name_x':'track_name', 'name_y':'artist'}, inplace = True)

# %%
data.head()
# Out:
#                  track_id                                         track_name  \
# 0  5CMVGP24paZIukljDj0iWc           Jingle Bells (with The Ken Lane Singers)
# 1  5CMVGP24paZIukljDj0iWc           Jingle Bells (with The Ken Lane Singers)
# 2  25leEEaz1gIpp7o21Fqyjo  Here Comes Santa Claus (Right Down Santa Claus...
# 3  1dtIaSlyrLI04sqYa8nLyN                     Rudolph the Red-Nosed Reindeer
# 4  4PS1e8f2LvuTFgUs1Cn3ON        The Christmas Song (Merry Christmas To You)
#
#    duration_ms release_date   album_type  explicit               artist_id  \
# 0       156666         1945  compilation     False  0TPlgv7eySSCChc2vKRIml
# 1       156666         1945  compilation     False  1Mxqyy3pSjf8kZZL4QVxS0
# 2       150266         1947        album     False  5ixB75BQR3ADoWQkcHQJTs
# 3       186733         1947        album     False  5ixB75BQR3ADoWQkcHQJTs
# 4       192160         1962        album     False  7v4imS0moSyGdXyLgVTIV7
#
#              artist  popularity  followers
# 0  Ken Lane Singers          28        151
# 1     Frank Sinatra          79    7480976
# 2        Gene Autry          48      71266
# 3        Gene Autry          48      71266
# 4     Nat King Cole          71    2312641

# %%
data = data.merge(chart_positions, on = 'track_id')

# %%
data.head()
# Out:
#                  track_id                                         track_name  \
# 0  5CMVGP24paZIukljDj0iWc           Jingle Bells (with The Ken Lane Singers)
# 1  5CMVGP24paZIukljDj0iWc           Jingle Bells (with The Ken Lane Singers)
# 2  5CMVGP24paZIukljDj0iWc           Jingle Bells (with The Ken Lane Singers)
# 3  5CMVGP24paZIukljDj0iWc           Jingle Bells (with The Ken Lane Singers)
# 4  25leEEaz1gIpp7o21Fqyjo  Here Comes Santa Claus (Right Down Santa Claus...
#
#    duration_ms release_date   album_type  explicit               artist_id  \
# 0       156666         1945  compilation     False  0TPlgv7eySSCChc2vKRIml
# 1       156666         1945  compilation     False  0TPlgv7eySSCChc2vKRIml
# 2       156666         1945  compilation     False  1Mxqyy3pSjf8kZZL4QVxS0
# 3       156666         1945  compilation     False  1Mxqyy3pSjf8kZZL4QVxS0
# 4       150266         1947        album     False  5ixB75BQR3ADoWQkcHQJTs
#
#              artist  popularity  followers  chart_week  list_position
# 0  Ken Lane Singers          28        151  2023-12-30             16
# 1  Ken Lane Singers          28        151  2024-01-06             16
# 2     Frank Sinatra          79    7480976  2023-12-30             16
# 3     Frank Sinatra          79    7480976  2024-01-06             16
# 4        Gene Autry          48      71266  2024-01-06             21

# %%
data = data[['track_name', 'artist', 'duration_ms', 
             'release_date', 'popularity', 'followers',
             'chart_week', 'list_position', 'track_id', 'artist_id']]

# %%
data['duration_ms'] = round(data['duration_ms']/1000, 2)

# %%
data['duration_ms'] = round(data['duration_ms']/60,1)

# %%
data = data.rename(columns = {'duration_ms':'duration_min'})

# %%
data.head()
# Out:
#                                           track_name            artist  \
# 0           Jingle Bells (with The Ken Lane Singers)  Ken Lane Singers
# 1           Jingle Bells (with The Ken Lane Singers)  Ken Lane Singers
# 2           Jingle Bells (with The Ken Lane Singers)     Frank Sinatra
# 3           Jingle Bells (with The Ken Lane Singers)     Frank Sinatra
# 4  Here Comes Santa Claus (Right Down Santa Claus...        Gene Autry
#
#    duration_min release_date  popularity  followers  chart_week  \
# 0           2.6         1945          28        151  2023-12-30
# 1           2.6         1945          28        151  2024-01-06
# 2           2.6         1945          79    7480976  2023-12-30
# 3           2.6         1945          79    7480976  2024-01-06
# 4           2.5         1947          48      71266  2024-01-06
#
#    list_position                track_id               artist_id
# 0             16  5CMVGP24paZIukljDj0iWc  0TPlgv7eySSCChc2vKRIml
# 1             16  5CMVGP24paZIukljDj0iWc  0TPlgv7eySSCChc2vKRIml
# 2             16  5CMVGP24paZIukljDj0iWc  1Mxqyy3pSjf8kZZL4QVxS0
# 3             16  5CMVGP24paZIukljDj0iWc  1Mxqyy3pSjf8kZZL4QVxS0
# 4             21  25leEEaz1gIpp7o21Fqyjo  5ixB75BQR3ADoWQkcHQJTs

# %%
#data = data.merge(audio_features, on = 'track_id')

# %% [markdown]
# ## Cleaning & joining

# %% [markdown]
# ### Cleaning audio_features
#
# Cleaned seperately for better visiblility of columns
#
# - Got rid of null values
# - Rounded and changed datatype of tempo-column from float to int
# - Dropped redundant time_signature column

# %%
audio_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10783 entries, 0 to 10782
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          10776 non-null  object
#  1   danceability      10776 non-null  float64
#  2   energy            10776 non-null  float64
#  3   key               10776 non-null  float64
#  4   loudness          10776 non-null  float64
#  5   mode              10776 non-null  float64
#  6   speechiness       10776 non-null  float64
#  7   acousticness      10776 non-null  float64
#  8   instrumentalness  10776 non-null  float64
#  9   liveness          10776 non-null  float64
#  10  valence           10776 non-null  float64
#  11  tempo             10776 non-null  float64
#  12  time_signature    10776 non-null  float64
# dtypes: float64(12), object(1)
# memory usage: 1.1+ MB

# %%
# Getting rid of null values since they are not going to be of use for us.
audio_features.dropna(inplace=True)

# %%
# rounding and changing datatype of tempo to int
audio_features['tempo'] = round(audio_features['tempo']).astype('int')

# %%
# dropping redundant columns
audio_features.drop(columns = 'time_signature', inplace=True)

# %% [markdown]
# ### Cleaning the rest of the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188366 entries, 0 to 188365
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   track_name     188366 non-null  object
#  1   artist         188366 non-null  object
#  2   duration_min   188366 non-null  Float64
#  3   release_date   188366 non-null  object
#  4   popularity     188366 non-null  Int64
#  5   followers      188366 non-null  Int64
#  6   chart_week     188366 non-null  dbdate
#  7   list_position  188366 non-null  Int64
#  8   track_id       188366 non-null  object
#  9   artist_id      188366 non-null  object
# dtypes: Float64(1), Int64(3), dbdate(1), object(5)
# memory usage: 15.1+ MB

# %%
data['release_date'] = data['release_date'].str[:4]

# %%
data['release_date'] = pd.to_datetime(data['release_date'], format = '%Y')

# %%
data['release_date'] = data['release_date'].dt.year

# %%
data = data.rename(columns = {'release_date': 'release_year'})

# %%
# mask for filtering out songs released in 2000-2009
# mask = data[(data['release_year'] >= 2000) & (data['release_year'] <= 2009)]

# %%
data = data[data['release_year']>=2000]

# %%
data['chart_week'] = pd.to_datetime(data['chart_week'], format='%Y-%m-%d')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 183612 entries, 848 to 188365
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   track_name     183612 non-null  object
#  1   artist         183612 non-null  object
#  2   duration_min   183612 non-null  Float64
#  3   release_year   183612 non-null  int32
#  4   popularity     183612 non-null  Int64
#  5   followers      183612 non-null  Int64
#  6   chart_week     183612 non-null  datetime64[ns]
#  7   list_position  183612 non-null  Int64
#  8   track_id       183612 non-null  object
#  9   artist_id      183612 non-null  object
# dtypes: Float64(1), Int64(3), datetime64[ns](1), int32(1), object(4)
# memory usage: 15.4+ MB

# %%
data.head()
# Out:
#                track_name        artist  duration_min  release_year  \
# 848  He Wasn't Man Enough  Toni Braxton           4.4          2000
# 849  He Wasn't Man Enough  Toni Braxton           4.4          2000
# 850  He Wasn't Man Enough  Toni Braxton           4.4          2000
# 851  He Wasn't Man Enough  Toni Braxton           4.4          2000
# 852  He Wasn't Man Enough  Toni Braxton           4.4          2000
#
#      popularity  followers chart_week  list_position                track_id  \
# 848          65    4234164 2000-05-06              2  7f1Dmr246cJ9uQYdbplTbh
# 849          65    4234164 2000-05-13              2  7f1Dmr246cJ9uQYdbplTbh
# 850          65    4234164 2000-04-29              3  7f1Dmr246cJ9uQYdbplTbh
# 851          65    4234164 2000-05-20              4  7f1Dmr246cJ9uQYdbplTbh
# 852          65    4234164 2000-05-27              4  7f1Dmr246cJ9uQYdbplTbh
#
#                   artist_id
# 848  3X458ddYA2YcVWuVIGGOYe
# 849  3X458ddYA2YcVWuVIGGOYe
# 850  3X458ddYA2YcVWuVIGGOYe
# 851  3X458ddYA2YcVWuVIGGOYe
# 852  3X458ddYA2YcVWuVIGGOYe

# %%
data = data.merge(audio_features, on = 'track_id')

# %%
data = data.drop_duplicates()

# %%
data = data.reset_index(drop=True)

# %%
final_data = data[(data['release_year'] >= 2000) & (data['release_year'] <= 2009)]

# %%
final_data["Peaceful_lounge_music"] = (
    (final_data["danceability"].between(0.2, 0.6)) &
    (final_data["tempo"] < 110) &
    (final_data["energy"].between(0.1, 0.4)) &
    (final_data["speechiness"] < 0.3)
).astype(int)
lounge_and_peaceful_music = final_data[final_data["Peaceful_lounge_music"] == 1]
lounge_and_peaceful_music_unique = lounge_and_peaceful_music.drop_duplicates(subset="track_name", keep='first')
# Out:
# /var/folders/07/6xmdlmfd5l92rywy9n5wmrhh0000gn/T/ipykernel_92650/2560461678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data["Peaceful_lounge_music"] = (

# %%
lounge_and_peaceful_music_unique.sort_values('artist')
# Out:
#                                                track_name            artist  \
# 25067                                            Miss You           Aaliyah
# 29859                                  Like Red On a Rose      Alan Jackson
# 43410          Empire State of Mind (Part II) Broken Down       Alicia Keys
# 22458                                        Goodbye Time     Blake Shelton
# 10156                                   I Wish You'd Stay      Brad Paisley
# 25656     When I Get Where I'm Going (feat. Dolly Parton)      Brad Paisley
# 32916                                           I'll Walk   Bucky Covington
# 4211                                       Temporary Home  Carrie Underwood
# 3825                                  Stealing Cinderella       Chuck Wicks
# 38569                      I'm Alive (with Dave Matthews)     Dave Matthews
# 39698                                           Permanent        David Cook
# 8629                                            Only Time              Enya
# 6238    Where Are You Christmas - From "Dr. Seuss' How...        Faith Hill
# 43158   Maybe This Time (Glee Cast Version) (feat. Kri...         Glee Cast
# 21376                         When I Think About Cheatin'   Gretchen Wilson
# 120664                                              Never            Jaheim
# 25633                                    Goodbye My Lover       James Blunt
# 26818                                     Ordinary People       John Legend
# 35411                                          Hallelujah      Kate Voegele
# 13497                           A Lot of Things Different     Kenny Chesney
# 33955                                  Better As A Memory     Kenny Chesney
# 42890                             The House That Built Me   Miranda Lambert
# 6314                                                 Love   Musiq Soulchild
# 38731                                  Glitter In the Air              P!nk
# 42787                                        Just Breathe         Pearl Jam
# 21578                                                True      Ryan Cabrera
# 3211                                                River   Sarah McLachlan
# 12835                                      I Need You Now     Smokie Norful
# 28435                       Set The Fire To The Third Bar       Snow Patrol
# 111631                                             Bother        Stone Sour
# 43269                                   I Dreamed a Dream       Susan Boyle
# 43273                                         Wild Horses       Susan Boyle
# 39315                                         White Horse      Taylor Swift
# 42409                                       I Look to You   Whitney Houston
#
#         duration_min  release_year  popularity  followers chart_week  \
# 25067            4.1          2005          69    4558858 2003-04-05
# 29859            3.6          2006          74    2878853 2006-10-14
# 43410            3.6          2009          81   12131689 2010-01-02
# 22458            3.4          2004          73    7252097 2005-07-23
# 10156            6.3          2001          68    2822412 2003-02-22
# 25656            4.1          2005          68    2822412 2006-02-25
# 32916            3.5          2007          35     145631 2008-11-15
# 4211             4.5          2009          72    5998552 2010-04-03
# 3825             4.0          2008          33     105933 2008-03-22
# 38569            3.3          2008          56     409494 2009-11-28
# 39698            2.9          2008          43     327269 2009-06-06
# 8629             3.6          2000          73    2260578 2001-11-10
# 6238             4.1          2000          63    1869329 2001-01-06
# 43158            3.0          2009          70    1516672 2009-10-17
# 21376            4.2          2004          56     936245 2005-01-29
# 120664           4.4          2007          56    1461316 2008-03-22
# 25633            4.3          2005          72    3040674 2006-03-25
# 26818            4.7          2005          77    7075416 2005-03-26
# 35411            4.9          2008          37     133517 2008-05-31
# 13497            4.7          2002          72    4549371 2002-12-21
# 33955            4.2          2007          72    4549371 2008-06-28
# 42890            3.9          2009          71    3613636 2010-06-05
# 6314             5.1          2000          59    1162356 2001-03-31
# 38731            3.8          2008          82   17190703 2010-02-20
# 42787            3.6          2009          76    9075047 2010-03-27
# 21578            3.4          2004          44     102040 2005-01-29
# 3211             4.0          2006          63     900323 2006-12-30
# 12835            4.2          2002          45     351587 2003-11-29
# 28435            3.4          2006          71    3061615 2010-02-06
# 111631           4.0          2002          65    2933178 2002-11-23
# 43269            3.2          2009          47     250488 2009-12-12
# 43273            4.9          2009          47     250488 2009-12-12
# 39315            3.9          2008         100  123544806 2008-11-29
# 42409            4.4          2009          77   10507909 2009-09-19
#
#         list_position                track_id               artist_id  \
# 25067               3  6qzgPGToY6vUtEAYfZLl14  0urTpYCsixqZwgNTkPJOJ4
# 29859              80  1ayFArNqsYgGT8gWWSscTD  4mxWe1mtYIYfP040G38yvS
# 43410              55  5sra5UY6sD658OabHL3QtI  3DiDSECUqqY1AuBP8qtaIa
# 22458              73  1M9qgq0SaZ5OuAeU0GKXif  1UTPBmNbXNTittyMJrNkvw
# 10156              57  1Jhm8RRMQSTYX9ZaOMeUk8  13YmWQJFwgZrd4bf5IjMY4
# 25656              39  3VLCtStwYsAL4LKZgeUvy3  13YmWQJFwgZrd4bf5IjMY4
# 32916              70  3WsAMhyOHxYPrL1pyMAVZm  5sVu3ObJTpiln7yRQkMuje
# 4211               41  0d0tJF80562KcMndcBcSfM  4xFUf1FHVy696Q1JQZMTRj
# 3825               56  6aOdhGqD0xuFM0OauOedNl  696fbyLHSMBSYjDrDU5yiK
# 38569              32  12Nri9FR6o4Gpmrll3O2rW  13vQloYd6mP7V1mVwKJwS2
# 39698              24  7bppBAD4NHqVqzXkrkZVxY  4SQxI8xg6LcSWL3KuGVHLa
# 8629               10  6FLwmdmW77N1Pxb1aWsZmO  6uothxMWeLWIhsGeF7cyo4
# 6238               65  1msuiw6pnXYfxZ7Edyit9U  25NQNriVT2YbSW80ILRWJa
# 43158              88  6cUf9i28VLmBKCBTyiS4vT  0SCbttzoZTnLFebDYmAWCm
# 21376              39  05jSCFSAfFqhrk3UiEvTDX  0IdYRFTswLdsGwSnzOaGNF
# 120664             76  0mRwNBO4xlQGW6SSGXPHBV  4sbB4Yy6Qig51pKCIKSLw3
# 25633              66  6gxycjJNMgmAyfzUXBN80P  7KMqksf0UMdyA0UCf4R3ux
# 26818              24  2ZA4uMlSZjaoWGFqP1tsLI  5y2Xq6xcjJb2jVM54GHK3t
# 35411              68  5OqW09kxGmc6b5xGFmln1b  7whckrkkTMEuvqfaNfMs7S
# 13497              55  1Hy3tvcg6l5o4codLnOC8f  3grHWM9bx2E9vwJCdlRv9O
# 33955              46  5Wz9a5T5T3JgVDxMpX9BFu  3grHWM9bx2E9vwJCdlRv9O
# 42890              28  02eD9ymfJOJOhM97HYp5R9  66lH4jAE7pqPlOlzUKbwA0
# 6314               24  6uSa5iCMwPr10Ftpz8w09b  3UVRliakQfa1pMWIsNuiZ8
# 38731              18  1M6dQ8MZQnYxjH8yZzswQt  1KCSPY1glIKqW2TotWuXOR
# 42787              78  6i81qFkru6Kj1IEsB7KNp2  1w5Kfo2jwwIPruYS2UWh56
# 21578              18  0jdeV5dSB3kUBRqe1xQJbh  3C4t1usFGoKHCSRdujm2GN
# 3211               71  3yLCQ4GRSFlg3GmwlYQlzX  4NgNsOXSwIzXlUIJcpnNUp
# 12835              96  44q2DhInsQYJ8X1q2H1RNj  0sD8Amms4kSxs5tBV4CUmR
# 28435              54  5g0afUZsh5hiXBOT3eXuwd  3rIZMv9rysU7JkLzEaC5Jp
# 111631             56  0AfIsqZ4gTUg9CwwW2jLeK  49qiE8dj4JuNdpYGRPdKbF
# 43269              62  6umBxaxgV2q52o3Q8wH2Ma  1qAuetfG6mhtDgsVIffWQc
# 43273              98  70rEifmDizVTzvvuUMEITz  1qAuetfG6mhtDgsVIffWQc
# 39315              13  6wn61Fzx9XMxQmieLpoIhW  06HL4z0CvFAxyc27GXpf02
# 42409              70  1rAESNsSXvXpJh9hCjgHVX  6XpaIBNiVzIetEPCWDvAFP
#
#         danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 25067          0.588   0.353  10.0    -9.465   1.0       0.0372         0.588
# 29859          0.598   0.315  11.0    -9.830   1.0       0.0282         0.634
# 43410          0.484   0.368   6.0    -7.784   1.0       0.0341         0.740
# 22458          0.510   0.348   2.0    -7.849   1.0       0.0261         0.295
# 10156          0.472   0.290   7.0   -10.238   1.0       0.0257         0.286
# 25656          0.519   0.379   0.0    -9.906   1.0       0.0279         0.619
# 32916          0.509   0.389   7.0    -7.433   1.0       0.0272         0.800
# 4211           0.416   0.354   0.0    -6.357   1.0       0.0263         0.731
# 3825           0.486   0.394   8.0    -8.728   1.0       0.0305         0.454
# 38569          0.564   0.244   3.0   -11.149   1.0       0.0329         0.758
# 39698          0.577   0.336   5.0    -7.263   1.0       0.0303         0.804
# 8629           0.418   0.249   3.0   -13.744   1.0       0.0301         0.841
# 6238           0.266   0.333  10.0    -9.876   1.0       0.0310         0.590
# 43158          0.399   0.382   6.0    -8.110   1.0       0.1680         0.460
# 21376          0.495   0.387   9.0    -7.531   1.0       0.0256         0.617
# 120664         0.537   0.337   4.0    -8.117   1.0       0.0728         0.224
# 25633          0.432   0.261   4.0   -12.591   1.0       0.0512         0.953
# 26818          0.469   0.132  10.0   -14.001   1.0       0.0798         0.928
# 35411          0.593   0.217   2.0    -7.474   0.0       0.0282         0.936
# 13497          0.589   0.279   2.0   -13.693   1.0       0.0285         0.129
# 33955          0.576   0.302   2.0   -11.845   1.0       0.0330         0.433
# 42890          0.525   0.300   5.0    -8.005   1.0       0.0286         0.578
# 6314           0.569   0.385   1.0    -9.919   0.0       0.0499         0.342
# 38731          0.514   0.255   5.0   -12.037   1.0       0.0283         0.898
# 42787          0.473   0.348   0.0   -11.100   1.0       0.0288         0.721
# 21578          0.598   0.400   6.0   -10.054   1.0       0.0241         0.459
# 3211           0.564   0.336  10.0   -11.739   1.0       0.0283         0.817
# 12835          0.339   0.273   5.0    -9.945   0.0       0.0309         0.729
# 28435          0.547   0.368  11.0    -7.053   0.0       0.0255         0.537
# 111631         0.272   0.281   1.0    -7.634   1.0       0.0287         0.388
# 43269          0.286   0.378  10.0    -8.752   1.0       0.0382         0.803
# 43273          0.230   0.152   8.0   -13.992   1.0       0.0353         0.911
# 39315          0.578   0.340   0.0    -8.027   1.0       0.0264         0.305
# 42409          0.550   0.373   4.0    -6.310   1.0       0.0286         0.717
#
#         instrumentalness  liveness  valence  tempo  Peaceful_lounge_music
# 25067           0.000000    0.1290   0.5160    109                      1
# 29859           0.191000    0.0825   0.1720     97                      1
# 43410           0.000038    0.1180   0.1420     93                      1
# 22458           0.000025    0.2420   0.1590     77                      1
# 10156           0.000072    0.2870   0.0906     94                      1
# 25656           0.000002    0.1080   0.2080     86                      1
# 32916           0.000000    0.1130   0.3020     77                      1
# 4211            0.000001    0.0925   0.1810     81                      1
# 3825            0.000016    0.1220   0.3200     69                      1
# 38569           0.000607    0.1060   0.3460     78                      1
# 39698           0.000000    0.1030   0.1540     96                      1
# 8629            0.661000    0.1120   0.2130     83                      1
# 6238            0.000000    0.1210   0.0796    109                      1
# 43158           0.000017    0.1190   0.1940     86                      1
# 21376           0.000004    0.3420   0.2910     78                      1
# 120664          0.000000    0.1070   0.6050    105                      1
# 25633           0.003420    0.0903   0.2730     90                      1
# 26818           0.000000    0.0873   0.3600     67                      1
# 35411           0.000000    0.1170   0.3650    108                      1
# 13497           0.019200    0.1490   0.2120     75                      1
# 33955           0.000033    0.1330   0.1450     71                      1
# 42890           0.000008    0.1160   0.2060     81                      1
# 6314            0.000000    0.0876   0.3390    100                      1
# 38731           0.000235    0.0994   0.2980    100                      1
# 42787           0.000074    0.0823   0.2830    108                      1
# 21578           0.000000    0.1510   0.3690     97                      1
# 3211            0.000587    0.1020   0.2550     98                      1
# 12835           0.000000    0.1520   0.3040     97                      1
# 28435           0.000000    0.0955   0.3670     96                      1
# 111631          0.000023    0.1580   0.1410     90                      1
# 43269           0.000518    0.1070   0.1130     69                      1
# 43273           0.004930    0.1220   0.1160     89                      1
# 39315           0.000000    0.1040   0.2230     93                      1
# 42409           0.000000    0.0960   0.1010    102                      1

# %%
round(lounge_and_peaceful_music_unique['duration_min'].sum()/60,2)
# Out:
# 2.29
